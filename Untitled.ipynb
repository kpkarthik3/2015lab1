# %%
df = DataFrame.from_dict({
'row0' : [1, 1+1j, 'A'],
'row1' : [2, 2+2j, 'B']
}, orient='index')
temp = DataFrame(np.random.rand(50,5))
#print(temp)
#print (temp.index)
len(temp)
temp.index = pd.date_range('1/1/2005',
periods=len(temp), freq='M')
# temp.index
temp.ndim
temp.tail(10)
#temp.iloc[:4, :4]
#print(temp)
#temp1= temp
#print( temp1.rank())
#temp.sort_values(by=[1,2])
temp.shape
#temp.to_csv('temp.csv')
temp.values
# Out:
# array([[ 0.4917475 ,  0.61503296,  0.95349494,  0.99621091,  0.96845371],
#        [ 0.23663824,  0.92507227,  0.90436039,  0.40427125,  0.78416992],
#        [ 0.11325076,  0.78048858,  0.3214297 ,  0.6282685 ,  0.87565611],
#        [ 0.11742727,  0.94393107,  0.8922497 ,  0.98526678,  0.71586839],
#        [ 0.27949385,  0.07835191,  0.794275  ,  0.51006387,  0.93768759],
#        [ 0.67596676,  0.56650727,  0.10002996,  0.91588135,  0.98678089],
#        [ 0.32118336,  0.31431403,  0.25331016,  0.86208197,  0.65209616],
#        [ 0.61759475,  0.79529489,  0.66349172,  0.80443411,  0.42392877],
#        [ 0.72065228,  0.28858953,  0.32352108,  0.02207714,  0.47520555],
#        [ 0.68032689,  0.20002265,  0.53601592,  0.72752155,  0.57877214],
#        [ 0.55402235,  0.93259339,  0.62228376,  0.15241365,  0.3549912 ],
#        [ 0.28657571,  0.20604239,  0.99775656,  0.11883193,  0.36609046],
#        [ 0.20515132,  0.05445501,  0.56811265,  0.87666939,  0.12496131],
# ...

# %%
import numpy as np # imports a fast numerical programming library
import scipy as sp #imports stats functions, amongst other things
import matplotlib as mpl # this actually imports matplotlib
import matplotlib.cm as cm #allows us easy access to colormaps
import matplotlib.pyplot as plt #sets up plotting under plt
import pandas as pd #lets us handle data as dataframes
import math as m
from math import cos, pi

from pandas import DataFrame, Series # series functions

# %%
temp.mul(100)
temp.where(temp[1] > 100)
df= temp
df.filter(items=[5], axis=1) # by rowdf
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
temp.columns
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.columns.values
# Out:
# array([0, 1, 2, 3, 4])

# %%
print( df[['col1', 'col2']])

df
# Out:
#                 col1      col2
# 2005-01-31  0.491748  0.615033
# 2005-02-28  0.236638  0.925072
# 2005-03-31  0.113251  0.780489
# 2005-04-30  0.117427  0.943931
# 2005-05-31  0.279494  0.078352
# 2005-06-30  0.675967  0.566507
# 2005-07-31  0.321183  0.314314
# 2005-08-31  0.617595  0.795295
# 2005-09-30  0.720652  0.288590
# 2005-10-31  0.680327  0.200023
# 2005-11-30  0.554022  0.932593
# 2006-07-31    0.086750
# 2006-08-31    0.942249
# 2006-09-30    0.065245
# 2006-10-31    0.378736
# 2006-11-30    0.422496
# 2006-12-31    0.267182
# 2007-01-31    0.525432
# 2007-02-28    0.024915
# 2007-03-31    0.946219
# 2007-04-30    0.187793
# 2007-05-31    0.209993
# 2007-06-30    0.022441
# 2007-07-31    0.288450
# 2007-08-31    0.575512
# 2007-09-30    0.038446
# 2007-10-31    0.592816
# 2007-11-30    0.258904
# 2007-12-31    0.383419
# 2008-01-31    0.384156
# 2008-02-29    0.779317
# 2008-03-31    0.155146
# 2008-04-30    0.540131
# ...

# %%
491748
2005-02-28    0.236638
2005-03-31    0.113251
2005-04-30    0.117427
2005-05-31    0.279494

0.491748
2005-02-28     0.728386
2005-03-31     0.841636
2005-04-30     0.95906
# Out:
#   File "<ipython-input-129-0507c0d24de5>", line 2
#     2005-02-28    0.236638
#           ^
# SyntaxError: invalid token

# %%
df.columns.get_loc('col3')
# Out:
# 2

# %%
import chardet

# %%
#import codecs
#f = codecs.open("/Users/user/Downloads/Date and Location data1.csv", 'r', encoding='utf-8')
with open('/Users/user/Downloads/Date and Location data1.csv', 'rb') as f:
 result = chardet.detect(f.readline(5))  # or readline if the file is large
 #print(result)
#readline?
temp = pd.read_csv('/Users/user/Downloads/Date and Location data1.csv',\
     names=['Campaign','Ad group','Most specific location', 'Region',\
            'Day','Impressions','Clicks', 'Cost'],\
                  dtype={"Ad group": str, "Most specific location": str}, encoding=result['encoding'])

# %%
 temp.head(100)
# Out:
#                                              Campaign             Ad group  \
# 0   Campaign\tAd group\tMost specific location\tRe...                  NaN
# 1   Search-US (Glossary Keywords)\tKnowledge Base\...   2016"\t1\t0\t$0.00
# 2   Search-US (Glossary Keywords)\tSelf Service\tO...   2016"\t1\t0\t$0.00
# 3   Search-US (Glossary Keywords)\tSelf Service\tP...   2016"\t1\t0\t$0.00
# 4   Search-US (Glossary Keywords)\tKnowledge Base\...   2016"\t1\t0\t$0.00
# 5   Search-US (Glossary Keywords)\tIvr System\t302...   2016"\t1\t0\t$0.00
# 6   Search-US (Glossary Keywords)\tSelf Service\tM...   2016"\t1\t0\t$0.00
# 7   Search-US (Glossary Keywords)\tInteractive Voi...   2016"\t0\t0\t$0.00
# 8   Search-US (Glossary Keywords)\tSelf Service\tN...   2016"\t1\t0\t$0.00
# 9   Search-US (Glossary Keywords)\tKnowledge Base\...   2016"\t2\t0\t$0.00
# 10  Search-US (Glossary Keywords)\tIvr Voice\t7570...   2016"\t1\t0\t$0.00
# ...
